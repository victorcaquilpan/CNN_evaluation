# %%
# Loading packages
from google.colab import drive
import os
from torchvision import transforms 
from torchvision.datasets import ImageFolder
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import random_split
from torchvision.utils import make_grid
from torch.utils.data.dataloader import DataLoader
import torch.optim as optim
import random
from tqdm.notebook import tqdm
import numpy as np

# Also, as we have a auxiliar python file with function, we go to use it
from cnn_functions import *

# %%
# As our dataset is mounted in Google Drive, we need to get access to it.
drive.mount('/content/drive')

# Dataset path. You should change the dataset path to the location that you place the data.
data_dir = '/content/drive/MyDrive/DeepLearning/dataset/'
classes = os.listdir(data_dir)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Performing Image Transformations. 
train_transform = transforms.Compose([
            transforms.Resize(256),
            transforms.RandomHorizontalFlip(),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

# %%
# Checking the dataset training size
dataset = ImageFolder(data_dir, transform=train_transform)
print('Size of training dataset :', len(dataset))
# Out:
# Size of training dataset : 5400

# %%
# Viewing one of images shape
img, label = dataset[100]
print(img.shape)
# Out:
# torch.Size([3, 224, 224])

# %%
# Setting seed so that value won't change everytime
# Splitting the dataset to training, validation, and testing category
torch.manual_seed(1)
val_size = len(dataset)//20
test_size = len(dataset)//10
train_size = len(dataset) - val_size - test_size

# %%
# Random Splitting
train_ds, val_ds, test_ds = random_split(dataset, [train_size, val_size, test_size])
# Check the size of each dataset
len(train_ds), len(val_ds),len(test_ds)
# Out:
# (4590, 270, 540)

# %%
# Define batch size
batch_size = 12
# Define a generator of random values
g_cpu = torch.Generator()
g_cpu.manual_seed(123)
train_loader = DataLoader(train_ds, batch_size, shuffle=True, num_workers=2, pin_memory=True,generator  = g_cpu)
val_loader = DataLoader(val_ds, batch_size, num_workers=2, pin_memory=True)
test_loader = DataLoader(test_ds, batch_size, num_workers=2, pin_memory=True)

# %%
# We can see some of these images available in one batch
for images, labels in train_loader:
    fig, ax = plt.subplots(figsize=(18,10))
    ax.set_xticks([])
    ax.set_yticks([])
    ax.imshow(make_grid(images, nrow=6).permute(1, 2, 0))
    break
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Now, we go to consider some parameters to start to create our models
input_size = torch.randn(1, 3, 224, 224)
output_size = 90

# Pass our data to GPU
device = get_default_device()
device
train_loader = DeviceDataLoader(train_loader, device)
val_loader = DeviceDataLoader(val_loader, device)
test_loader = DeviceDataLoader(test_loader, device)

# %% [markdown]
# # **Create Basic CNN Model**

# %%
# First, it is necessary create a class
class BasicCNN(nn.Module):
    def __init__(self,classes):
      super().__init__()
      self.num_classes=classes
      self.conv1=nn.Conv2d(3,64,5,1)
      self.conv2=nn.Conv2d(64,128,3,1)
      self.conv3=nn.Conv2d(128,128,3,1)
      self.conv4=nn.Conv2d(128,128,3,1)
      self.fc1=nn.Linear(18432,self.num_classes)

    def forward(self,X):
      X=F.relu(self.conv1(X)) 
      X=F.max_pool2d(X,2,2)
      X=F.relu(self.conv2(X))
      X=F.max_pool2d(X,2,2)
      X=F.relu(self.conv3(X))
      X=F.max_pool2d(X,2,2)
      X=F.relu(self.conv4(X))
      X=F.max_pool2d(X,2,2)
      X=X.view(-1,18432)
      X=self.fc1(X)

      # Apply softmax to x
      output = F.log_softmax(X, dim=1)
      return output

# %%
# Reporting the Flops of this model
print_model_parm_flops(BasicCNN(90),input_size, detail=False)
# Out:
#  + Number of FLOPs: 3.07G

# %% [markdown]
# # **Basic CNN, Loss function: Cross entropy, Optimizer: SGD, learning rate:0.01, epochs:20**

# %%
cnn_sgd_lr001_performance = fit_model(BasicCNN(90),train_loader = train_loader,val_loader = val_loader,test_loader =test_loader,optimization = 'SGD',loss_function = 'Cross-entropy',epochs = 20,learning_rate = 0.01)
# Out:
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.455
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.340
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.291
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.186
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:3.998
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:3.616
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:3.243
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:2.754
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:2.373
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:2.071
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:1.857
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:1.607
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:1.630
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:1.183
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:1.068
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:0.827
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:0.927
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:0.828
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:0.851
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:0.818
# Finished Training

# %%
# Plot results
plot_performance(cnn_sgd_lr001_performance[1],cnn_sgd_lr001_performance[2])

# %%
# Reporting test accuracy
print(f'Accuracy in testing is: {cnn_sgd_lr001_performance[3][0].cpu()}')
# Out:
# Accuracy in testing is: 0.3055555522441864

# %% [markdown]
# # **Basic CNN, Loss function: Cross entropy, Optimizer: SGD, learning rate:0.1, epochs:20**

# %%
cnn_sdg_lr01_performance = fit_model(BasicCNN(90),train_loader = train_loader,val_loader = val_loader,test_loader =test_loader,optimization = 'SGD',loss_function = 'Cross-entropy',epochs = 20,learning_rate = 0.1)
# Out:
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.523
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.528
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.527
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.526
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.526
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.526
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.525
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.527
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.529
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.527
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.527
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.527
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.527
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.525
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.526
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.525
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.527
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.526
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.527
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.525
# Finished Training

# %%
# Plot results
plot_performance(cnn_sdg_lr01_performance[1],cnn_sdg_lr01_performance[2])

# %%
# Reporting test accuracy
print(f'Accuracy in testing is: {cnn_sdg_lr01_performance[3][0].cpu()}')
# Out:
# Accuracy in testing is: 0.009259260259568691

# %% [markdown]
# # **Basic CNN, Loss function: Cross entropy, Optimizer: Adam, learning rate:0.01, epochs:20**

# %%
cnn_adam_lr001_performance = fit_model(BasicCNN(90),train_loader = train_loader,val_loader = val_loader,test_loader =test_loader,optimization = 'Adam',loss_function = 'Cross-entropy',epochs = 20,learning_rate = 0.01)
# Out:
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:6.845
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.510
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.509
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.510
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.509
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.509
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.510
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.509
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.510
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.509
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.509
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.509
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.509
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.510
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.509
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.509
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.510
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.509
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.509
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.510
# Finished Training

# %%
# Plot results
plot_performance(cnn_adam_lr001_performance[1],cnn_adam_lr001_performance[2])

# %%
# Reporting test accuracy
print(f'Accuracy in testing is: {cnn_adam_lr001_performance[3][0].cpu()}')
# Out:
# Accuracy in testing is: 0.003703703870996833

# %% [markdown]
# # **Basic CNN, Loss function: Cross entropy, Optimizer: ADAM, learning rate:0.1, epochs:20**

# %%
cnn_adam_lr01_performance = fit_model(BasicCNN(90),train_loader = train_loader,val_loader = val_loader,test_loader =test_loader,optimization = 'Adam',loss_function = 'Cross-entropy',epochs = 20,learning_rate = 0.1)
# Out:
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:76219.316
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.571
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.574
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.579
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.577
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.577
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.574
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.578
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.573
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.571
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.576
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.576
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.573
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.574
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.576
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.579
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.577
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.578
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.576
#   0%|          | 0/383 [00:00<?, ?it/s]
# [loss in training]:4.579
# Finished Training

# %%
# Plot results
plot_performance(cnn_adam_lr01_performance[1],cnn_adam_lr01_performance[2])

# %%
# Reporting test accuracy
print(f'Accuracy in testing is: {cnn_adam_lr01_performance[3][0].cpu()}')
# Out:
# Accuracy in testing is: 0.020370367914438248
